# %% [markdown]
# # Number Guessing Game
#
# In this project, we will create a **Number Guessing Game** where the computer selects a random number, and the user tries to guess it. The program provides hints if the guessed number is too high or too low.

# %% [markdown]
# ### Step 1: Importing Required Libraries
# We'll need the `random` library to make our program select a random number.

# %%
# Importing the random library
import random

# %% [markdown]
# ### Step 3: Writing the Guessing Loop
# We'll use a `while` loop to keep asking the user for guesses until they guess correctly.
#
# - The program will increment the attempt counter each time the user makes a guess.
# - If the guess is too high, it will tell the user.
# - If the guess is too low, it will also inform the user.
# - When the user guesses correctly, the program congratulates them and ends the game.

# %%
#This is the number that the player should guess

# %% [markdown]
# ### Step 2: Setting Up the Game Logic
#
#
#
#
#
#
#
#
# - The computer will randomly choose an integer between 0 and 5000.
# - The user will guess a number, and the program will respond with whether the guess is too high, too low, or correct.
# - The goal is to guess the correct number with the fewest attempts possible.
# -
# _
# _

# %%
import random
from re import I
# Write your code here
secret_number = random.randint(0, 5000)
user_number = secret_number + 1
while secret_number != user_number:
  user_number=int(input("Guess a number between 0 and 5000"))
  if user_number>secret_number:
    print("Too High")
  elif user_number<secret_number:
    print("Too Low")
else:
  print("Correct")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2496/2768197016.py in <cell line: 0>()
#       1 from re import I
#       2 # Write your code here
# ----> 3 secret_number = random.randint(0, 5000)
#       4 user_number = secret_number + 1
#       5 while secret_number != user_number:
#
# NameError: name 'random' is not defined

# %% [markdown]
# ### Extension Ideas:
# - **Set a Limit on Attempts**: You could make the game more challenging by limiting the number of attempts.
# - **Difficulty Levels**: Offer different ranges depending on the difficulty level (e.g., Easy: 0-100, Medium: 0-1000, Hard: 0-5000).
# - **Provide Hints**: Give hints based on how close the guess is to the correct number.
# - **Make the game nicer**: Add some seperations between the code outputs by printing empty lines or "-----"
#
# Try adding these features to make the game more interesting!

# %% [markdown]
# ### Summary:
# In this project, you created a fun number guessing game using Python! This exercise helped you practice working with loops, conditionals, and user input. Great job!
#
# You can extend the game by adding more features or even create a graphical version of it using libraries like `tkinter`!
