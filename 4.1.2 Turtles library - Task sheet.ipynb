# %% [markdown]
# # Drawing shapes with the Turtles library (Project 4.1.2) - Task sheet

# %% [markdown]
# ---
#
#
# TURTLE DOESN'T WORK IN GOOGLE COLLAB, USE LOCAL INSTANCE
#
# ---

# %% [markdown]
# In this project, we will be controlling a robotic turtle on our screen using code. These exercises are, for one, supposed to be fun, and secondly, show you what Python is really about, namely (virtual) objects, which are controlled by code. You can read up on the turtles library, and the different functions it contains, here: https://docs.python.org/3/library/turtle.html

# %%
# !pip install mobilechelonian

# %%
from mobilechelonian import Turtle

myturtle = Turtle()

# %% [markdown]
# ## Customising your turtle's appearance
#
# For this purpose, check out the following functions. For each of them, please write one sentence saying what they do, and try changing their parameters.

# %%
myturtle

# %%
# What does the function bgcolor() do?

myturtle.bgcolor("red")

# %%
# What does the method .shape() do?

myturtle.shape("turtle")

# %% [markdown]
# ## Making your turtle move

# %% [markdown]
# A turtle can move forward, backward, left, and right. When moving forward and backward, the number you give as parameter indicates the number of steps. Try out the following commands, and also change the number to a few higher and lower values.

# %%
# Moving forward
myturtle.forward(100) # change this value

# %%
# Moving backward
myturtle.backward(100) # change this value

# %% [markdown]
# ## Turning in a certain direction
# When moving right and left, you can change the direction of the turtle by adding the exact degree you want it to turn. Try the following commands, and change the angle from 90 to, for example, 120, 45, 10 etc.

# %%
myturtle.right(90) # change this value

# %%
myturtle.left(90) # change this value

# %%
# What does this method do? Make your turtle move after changing the parameter to higher and lower values...
turtle.speed(2)

# %%
# What does the following method do?
myturtle.home()

# %% [markdown]
# You can end your program using the function turtle.done(), and reset the lines drawn by your turtles object using myturtle.reset()

# %%
myturtle.reset()

# %% [markdown]
# ## Exercises

# %%
# TASK 1: Write and call function that draws a square

# %%
myturtle.reset()

# %%
# TASK 2: Write and call a function that draws a circle

"""
# Hints:
- You will need a loop for this
- You can alternate between taking one step to the right and one step forward
- Try changing the number of iterations and "step sizes" and see what changes!
"""

# %%
myturtle.reset()

# %%
# TASK 3: Write and call a function that draws a hexagon

# %%
myturtle.reset()

# %%
# TASK 4: Write and call a function that draws a star

# %%
myturtle.reset()

# %%
# TASK 5: Draw your own name

# %%
myturtle.reset()

# %%
# TASK 6: Now come up with your own shapes! And keep in mind that you can have several turtle objects moving at the same time!
