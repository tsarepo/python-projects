# %% [markdown]
# # Coding a Hangman game

# %% [markdown]
# You know how the game of hangman works, try coding it in practice...
#
# The objective of this exercise is to work as indpendantly as possible, try to think of where you want to start and what kind of functions you would want to design.
#
# ***Pro tip: Start easy, and add complexity as the project advances!***
